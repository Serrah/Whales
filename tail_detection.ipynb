# %%
import glob
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimp
import os
import pandas as pd
from random import randint

targets = pd.read_csv("train.csv",sep=",")
# To do : one hot encoding

features = []

train = glob.glob('./train_sub/*.jpg')

for file in train:
    features.append(np.array(mpimp.imread(file)))

# Transform into array because easier to manipulate
features = np.array(features)
#targets = np.array(targets)

print("features shape", features.shape)
# Attention shape [nb images, 75, 75, 3] 3 parce que RGB
print("Targets shape", targets.shape)
# Target [nb images, 2]

####################
##### Show images
####################
for a in [randint(0, len(train)) for _ in range(5)]:
    img = mpimp.imread(train[a])
    plt.imshow(img, cmap="gray")
    plt.show()
# Out:
# ('features shape', (5L,))
# ('Targets shape', (9850, 2))
